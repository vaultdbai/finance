# %%
from finance.core import get_tickers as gt

# %%
df = gt.get_tickers_dataframe()

# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")

# %%
# get all stock info
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and power automate; and on-premises ERP and CRM applications. The Intelligent Cloud segment offers server products and cloud services, such as azure and other cloud services; SQL and windows server, visual studio, system center, and related client access licenses, as well as nuance and GitHub; and enterprise services including enterprise support services, industry solutions, and nuance professional services. The More Personal Computing segment offers Windows, including windows OEM licensing and other non-volume licensing of the Windows operating system; Windows commercial comprising volume licensing of the Windows operating system, windows cloud services, and other Windows commercial offerings; patent licensing; and windows Internet of Things; and devices, such as surface, HoloLens, and PC accessories. Additionally, this segment provides gaming, which includes Xbox hardware and content, and first- and third-party content; Xbox game pass and other subscriptions, cloud gaming, advertising, third-party disc royalties, and other cloud services; and search and news advertising, which includes Bing, Microsoft News and Edge, and third-party affiliates. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online, and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.',
#  'fullTimeEmployees': 221000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Satya  Nadella',
#    'age': 56,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'totalPay': 9276400,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bradford L. Smith LCA',
#    'age': 64,
#    'title': 'President & Vice Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2023,
#    'totalPay': 3591277,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Amy E. Hood',
#    'age': 51,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'totalPay': 3452196,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Judson B. Althoff',
#    'age': 49,
#    'title': 'Executive VP & Chief Commercial Officer',
#    'yearBorn': 1974,
#    'fiscalYear': 2023,
#    'totalPay': 3355797,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Christopher David Young',
#    'age': 51,
#    'title': 'Executive Vice President of Business Development, Strategy & Ventures',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'totalPay': 2460507,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alice L. Jolla',
#    'age': 56,
#    'title': 'Corporate VP & Chief Accounting Officer',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James Kevin Scott',
#    'age': 51,
#    'title': 'Executive VP of AI & CTO',
#    'yearBorn': 1972,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Brett  Iversen',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hossein  Nowbar',
#    'title': 'Chief Legal Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frank X. Shaw',
#    'title': 'Chief Communications Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 3,
#  'boardRisk': 4,
#  'compensationRisk': 2,
#  'shareHolderRightsRisk': 2,
#  'overallRisk': 1,
#  'governanceEpochDate': 1717200000,
#  'compensationAsOfEpochDate': 1703980800,
#  'irWebsite': 'http://www.microsoft.com/investor/default.aspx',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 442.57,
#  'open': 442.44,
#  'dayLow': 440.72,
#  'dayHigh': 450.928,
#  'regularMarketPreviousClose': 442.57,
#  'regularMarketOpen': 442.44,
#  'regularMarketDayLow': 440.72,
#  'regularMarketDayHigh': 450.928,
#  'dividendRate': 3.0,
#  'dividendYield': 0.0067000003,
#  'exDividendDate': 1723680000,
#  'payoutRatio': 0.24780001,
#  'fiveYearAvgDividendYield': 0.93,
#  'beta': 0.893,
#  'trailingPE': 38.921005,
#  'forwardPE': 36.217285,
#  'volume': 19973278,
#  'regularMarketVolume': 19973278,
#  'averageVolume': 18779598,
#  'averageVolume10days': 16105850,
#  'averageDailyVolume10Day': 16105850,
#  'bid': 448.25,
#  'ask': 448.65,
#  'bidSize': 100,
#  'askSize': 100,
#  'marketCap': 3332424597504,
#  'fiftyTwoWeekLow': 309.45,
#  'fiftyTwoWeekHigh': 450.94,
#  'priceToSalesTrailing12Months': 14.0855875,
#  'fiftyDayAverage': 418.0774,
#  'twoHundredDayAverage': 384.90024,
#  'trailingAnnualDividendRate': 2.93,
#  'trailingAnnualDividendYield': 0.0066204215,
#  'currency': 'USD',
#  'enterpriseValue': 3358638997504,
#  'profitMargins': 0.36426997,
#  'floatShares': 7421603274,
#  'sharesOutstanding': 7432309760,
#  'sharesShort': 43764126,
#  'sharesShortPriorMonth': 56321541,
#  'sharesShortPreviousMonthDate': 1713139200,
#  'dateShortInterest': 1715731200,
#  'sharesPercentSharesOut': 0.0058999998,
#  'heldPercentInsiders': 0.00054000004,
#  'heldPercentInstitutions': 0.73686,
#  'shortRatio': 2.18,
#  'shortPercentOfFloat': 0.0058999998,
#  'impliedSharesOutstanding': 7432309760,
#  'bookValue': 34.058,
#  'priceToBook': 13.164896,
#  'lastFiscalYearEnd': 1688083200,
#  'nextFiscalYearEnd': 1719705600,
#  'mostRecentQuarter': 1711843200,
#  'earningsQuarterlyGrowth': 0.199,
#  'netIncomeToCommon': 86181003264,
#  'trailingEps': 11.52,
#  'forwardEps': 12.38,
#  'pegRatio': 2.66,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1045526400,
#  'enterpriseToRevenue': 14.196,
#  'enterpriseToEbitda': 26.66,
#  '52WeekChange': 0.32634223,
#  'SandP52WeekChange': 0.24711585,
#  'lastDividendValue': 0.75,
#  'lastDividendDate': 1707868800,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'underlyingSymbol': 'MSFT',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'firstTradeDateEpochUtc': 511108200,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': 'b004b3ec-de24-385e-b2c1-923f10d3fb62',
#  'messageBoardId': 'finmb_21835',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 448.37,
#  'targetHighPrice': 559.62,
#  'targetLowPrice': 406.66,
#  'targetMeanPrice': 452.03,
#  'targetMedianPrice': 447.7,
#  'recommendationMean': 1.6,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 46,
#  'totalCash': 80013000704,
#  'totalCashPerShare': 10.766,
#  'ebitda': 125981999104,
#  'totalDebt': 106228998144,
#  'quickRatio': 1.132,
#  'currentRatio': 1.242,
#  'totalRevenue': 236583993344,
#  'debtToEquity': 41.963,
#  'revenuePerShare': 31.834,
#  'returnOnAssets': 0.1541,
#  'returnOnEquity': 0.38487998,
#  'freeCashflow': 61997998080,
#  'operatingCashflow': 110122999808,
#  'earningsGrowth': 0.2,
#  'revenueGrowth': 0.17,
#  'grossMargins': 0.69894,
#  'ebitdaMargins': 0.5325,
#  'operatingMargins': 0.44588003,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.2107}

# %%
# show meta information about the history (requires history() to be called first)
msft.history_metadata
# Out:
# MSFT: Period '1wk' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']
# {'currency': 'USD',
#  'symbol': 'MSFT',
#  'exchangeName': 'NMS',
#  'fullExchangeName': 'NasdaqGS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 511108200,
#  'regularMarketTime': 1718654400,
#  'hasPrePostMarketData': True,
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 448.37,
#  'fiftyTwoWeekHigh': 450.928,
#  'fiftyTwoWeekLow': 440.72,
#  'regularMarketDayHigh': 450.928,
#  'regularMarketDayLow': 440.72,
#  'regularMarketVolume': 19973278,
#  'chartPreviousClose': 427.87,
#  'previousClose': 442.57,
#  'scale': 3,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EDT',
#    'start': 1718697600,
#    'end': 1718717400,
#    'gmtoffset': -14400},
#   'regular': {'timezone': 'EDT',
#    'start': 1718717400,
#    'end': 1718740800,
#    'gmtoffset': -14400},
#   'post': {'timezone': 'EDT',
#    'start': 1718740800,
#    'end': 1718755200,
#    'gmtoffset': -14400}},
#  'tradingPeriods':                                           pre_start                   pre_end  \
#  Date
#  2024-06-11 00:00:00-04:00 2024-06-11 04:00:00-04:00 2024-06-11 09:30:00-04:00
#  2024-06-12 00:00:00-04:00 2024-06-12 04:00:00-04:00 2024-06-12 09:30:00-04:00
#  2024-06-13 00:00:00-04:00 2024-06-13 04:00:00-04:00 2024-06-13 09:30:00-04:00
#  2024-06-14 00:00:00-04:00 2024-06-14 04:00:00-04:00 2024-06-14 09:30:00-04:00
#  2024-06-17 00:00:00-04:00 2024-06-17 04:00:00-04:00 2024-06-17 09:30:00-04:00
#  2024-06-18 00:00:00-04:00 2024-06-18 04:00:00-04:00 2024-06-18 09:30:00-04:00
#
#                                                start                       end  \
#  Date
#  2024-06-11 00:00:00-04:00 2024-06-11 09:30:00-04:00 2024-06-11 16:00:00-04:00
#  2024-06-12 00:00:00-04:00 2024-06-12 09:30:00-04:00 2024-06-12 16:00:00-04:00
#  2024-06-13 00:00:00-04:00 2024-06-13 09:30:00-04:00 2024-06-13 16:00:00-04:00
#  2024-06-14 00:00:00-04:00 2024-06-14 09:30:00-04:00 2024-06-14 16:00:00-04:00
#  2024-06-17 00:00:00-04:00 2024-06-17 09:30:00-04:00 2024-06-17 16:00:00-04:00
#  2024-06-18 00:00:00-04:00 2024-06-18 09:30:00-04:00 2024-06-18 16:00:00-04:00
#
#                                           post_start                  post_end
#  Date
#  2024-06-11 00:00:00-04:00 2024-06-11 16:00:00-04:00 2024-06-11 20:00:00-04:00
#  2024-06-12 00:00:00-04:00 2024-06-12 16:00:00-04:00 2024-06-12 20:00:00-04:00
#  2024-06-13 00:00:00-04:00 2024-06-13 16:00:00-04:00 2024-06-13 20:00:00-04:00
#  2024-06-14 00:00:00-04:00 2024-06-14 16:00:00-04:00 2024-06-14 20:00:00-04:00
#  2024-06-17 00:00:00-04:00 2024-06-17 16:00:00-04:00 2024-06-17 20:00:00-04:00
#  2024-06-18 00:00:00-04:00 2024-06-18 16:00:00-04:00 2024-06-18 20:00:00-04:00  ,
#  'dataGranularity': '1h',
#  'range': '1wk',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
# show actions (dividends, splits, capital gains)
print(msft.actions)
print(msft.dividends)
print(msft.splits)
print(msft.capital_gains)  # only for mutual funds & etfs
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-09-21 00:00:00-04:00       0.00           2.0
# 1990-04-16 00:00:00-04:00       0.00           2.0
# 1991-06-27 00:00:00-04:00       0.00           1.5
# 1992-06-15 00:00:00-04:00       0.00           1.5
# 1994-05-23 00:00:00-04:00       0.00           2.0
# ...                              ...           ...
# 2023-02-15 00:00:00-05:00       0.68           0.0
# 2023-05-17 00:00:00-04:00       0.68           0.0
# 2023-08-16 00:00:00-04:00       0.68           0.0
# 2023-11-15 00:00:00-05:00       0.75           0.0
# 2024-02-14 00:00:00-05:00       0.75           0.0
#
# [90 rows x 2 columns]
# Date
# 2003-02-19 00:00:00-05:00    0.08
# 2003-10-15 00:00:00-04:00    0.16
# 2004-08-23 00:00:00-04:00    0.08
# 2004-11-15 00:00:00-05:00    3.08
# 2005-02-15 00:00:00-05:00    0.08
#                              ...
# 2023-02-15 00:00:00-05:00    0.68
# 2023-05-17 00:00:00-04:00    0.68
# 2023-08-16 00:00:00-04:00    0.68
# 2023-11-15 00:00:00-05:00    0.75
# 2024-02-14 00:00:00-05:00    0.75
# Name: Dividends, Length: 81, dtype: float64
# Date
# 1987-09-21 00:00:00-04:00    2.0
# 1990-04-16 00:00:00-04:00    2.0
# 1991-06-27 00:00:00-04:00    1.5
# 1992-06-15 00:00:00-04:00    1.5
# 1994-05-23 00:00:00-04:00    2.0
# 1996-12-09 00:00:00-05:00    2.0
# 1998-02-23 00:00:00-05:00    2.0
# 1999-03-29 00:00:00-05:00    2.0
# 2003-02-18 00:00:00-05:00    2.0
# Name: Stock Splits, dtype: float64
# Series([], dtype: object)

# %%
# show share count
msft.get_shares_full(start="2022-01-01", end=None)
# Out:
# 2022-01-27 00:00:00-05:00    7496869888
# 2022-02-04 00:00:00-05:00    7800719872
# 2022-02-05 00:00:00-05:00    7496869888
# 2022-02-11 00:00:00-05:00    7496869888
# 2022-03-04 00:00:00-05:00    7605040128
#                                 ...
# 2024-06-11 00:00:00-04:00    7432309760
# 2024-06-12 00:00:00-04:00    7432309760
# 2024-06-13 00:00:00-04:00    7432309760
# 2024-06-14 00:00:00-04:00    7432309760
# 2024-06-15 00:00:00-04:00    7432309760
# Length: 200, dtype: int64

# %%
msft.news
# Out:
# [{'uuid': 'efd00e73-68d1-3fdc-8bb2-ddcdc1435195',
#   'title': 'If I Could Only Buy 1 Artificial Intelligence (AI) Stock, This Would Be It',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/efd00e73-68d1-3fdc-8bb2-ddcdc1435195/if-i-could-only-buy-1.html',
#   'providerPublishTime': 1718708400,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/SvtU.6lNPhiPoCgz3IY_JA--~B/aD00OTA7dz03MjA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/motleyfool.com/adda5b8c05787d78c8dd8b4419e7ea7e',
#      'width': 720,
#      'height': 490,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/dkey25MVMmke.GMhOTT82w--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/adda5b8c05787d78c8dd8b4419e7ea7e',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOG', 'NVDA', 'MSFT', '^GSPC']},
#  {'uuid': 'f8392466-c8e9-35dc-8a48-b7dbffd95501',
#   'title': 'Dow Jones Futures Fall Ahead Of Retail Sales; Nvidia Stock Reverses Lower',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/f8392466-c8e9-35dc-8a48-b7dbffd95501/dow-jones-futures-fall-ahead.html',
#   'providerPublishTime': 1718708378,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/WAuaz6qrZ4OYu_AuKxC0vQ--~B/aD02MDA7dz0xMDY1O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f84dddde254e978a0083114ec56c1e2b',
#      'width': 1065,
#      'height': 600,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/IVbsawCKXte9EBfO391xMQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f84dddde254e978a0083114ec56c1e2b',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^DJI', 'COMP', '^GSPC', 'NVDA', 'NFLX', 'MSFT', 'AMZN']},
#  {'uuid': '05bf8cec-0b76-4493-b539-81ee05ddf1b5',
#   'title': 'AI enthusiasm prompts 3 Wall Street banks to raise stock market forecasts',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/ai-enthusiasm-prompts-3-wall-street-banks-to-raise-stock-market-forecasts-100027154.html',
#   'providerPublishTime': 1718704827,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/yCVEaODavyVgx_Axn0txtA--~B/aD0yMDAwO3c9MzAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2024-06/07be2ec0-21bb-11ef-bf7f-446c7123679b',
#      'width': 3000,
#      'height': 2000,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/IRdryWtOotcjDXae8x5zjg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2024-06/07be2ec0-21bb-11ef-bf7f-446c7123679b',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^IXIC',
#    'MSFT',
#    'GOOG',
#    'AAPL',
#    'QQQ',
#    '^GSPC',
#    'NVDA',
#    'AMZN',
#    '^DJI',
#    'SPY']},
#  {'uuid': 'ac1ad029-b2b8-3ca4-b725-872370460957',
#   'title': '1 Artificial Intelligence (AI) Stock Has Created Many Millionaires and Can Continue to Climb Higher',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/ac1ad029-b2b8-3ca4-b725-872370460957/1-artificial-intelligence.html',
#   'providerPublishTime': 1718704020,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/bIoumiWI.lHNHZGtl2T2Tg--~B/aD0yMTYwO3c9Mzg0MDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/d6f69ea1cdacab847c7d0b61c5e0105d',
#      'width': 3840,
#      'height': 2160,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/siN3qYs2WRGIHR_CUfmdbA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/d6f69ea1cdacab847c7d0b61c5e0105d',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': 'cef9bea6-5cee-3def-9a32-b4a69cae7d55',
#   'title': 'Microsoft has limited exposure to China, but US lawmakers still raise questions',
#   'publisher': 'South China Morning Post',
#   'link': 'https://finance.yahoo.com/news/microsoft-limited-exposure-china-us-093000106.html',
#   'providerPublishTime': 1718703000,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/LDGHwPSDRv.y5zOE8EqnLg--~B/aD0xMzMzO3c9MTk5OTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/south_china_morning_post_us_228/618a64ad0fbc9d33ee1db34dbff086e1',
#      'width': 1999,
#      'height': 1333,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/nAj6l6V_t4BYll85kq5ouA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/south_china_morning_post_us_228/618a64ad0fbc9d33ee1db34dbff086e1',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': '92afcd4b-74df-34ef-9775-8e19329a2f7e',
#   'title': 'Forget Nvidia: Wall Street Is Bullish on Another Unstoppable Artificial Intelligence (AI) Stock',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/92afcd4b-74df-34ef-9775-8e19329a2f7e/forget-nvidia%3A-wall-street-is.html',
#   'providerPublishTime': 1718703000,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/e3U7atZwyfzP9_9lD1qI2A--~B/aD03ODc7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/2d3093292b7e73bc91092cf122697359',
#      'width': 1400,
#      'height': 787,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/Ny7FzEzS7q82INk64Srbpg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/2d3093292b7e73bc91092cf122697359',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['AMD', 'NVDA', 'MSFT']},
#  {'uuid': '6930c032-1b7e-3460-9497-4b6b544f037a',
#   'title': 'Nvidia, Apple, and Microsoft Could Help This Stock-Split ETF Turn $200,000 Into $1 Million',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/6930c032-1b7e-3460-9497-4b6b544f037a/nvidia%2C-apple%2C-and-microsoft.html',
#   'providerPublishTime': 1718702460,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/iMO7nXTg0kDCgcMul.a4wg--~B/aD05MzM7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/50657e16e9a590259b5e1f794f8c597f',
#      'width': 1400,
#      'height': 933,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/QcwrEs5P0_fU6IF3e02T0g--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/50657e16e9a590259b5e1f794f8c597f',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['NVDA', 'AAPL', 'MSFT', '^GSPC']},
#  {'uuid': '7fe75b89-8b28-32c4-9533-2bfe81af78e4',
#   'title': 'Billionaire David Tepper Has 25% of His Portfolio Invested in 3 Brilliant AI Stocks',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/7fe75b89-8b28-32c4-9533-2bfe81af78e4/billionaire-david-tepper-has.html',
#   'providerPublishTime': 1718701920,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/YFYNAndCUeML7K61KryTLQ--~B/aD0xNDE0O3c9MjEyMTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/b85e0138058fff573fe8a65c926b61c8',
#      'width': 2121,
#      'height': 1414,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/MItJi2_xap2J.EdrX6k3QQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/b85e0138058fff573fe8a65c926b61c8',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT', 'NVDA', 'AMZN', '^GSPC']}]
