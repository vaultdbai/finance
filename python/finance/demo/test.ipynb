# %% [markdown]
# Download Schema

# %%
import os
from vaultdb import download
from duckdb import login
database_name = "test"
filename = f"/workspace/{database_name}.db"
if not os.path.isfile(filename):
    url = f"http://test-public-storage-440955376164.s3-website.us-east-1.amazonaws.com/catalogs/{database_name}.db"
    filename = download(url, filename)

# %% [markdown]
# Open Database and Login

# %%
import duckdb
connection = duckdb.login.cognito("vaultdb","test123", filename, aws_region="us-east-1")

# %%
connection.execute("SELECT * FROM vaultdb_configs").fetchdf()
# Out:
#   database_name  database_oid schema_name  schema_oid          config_name  \
# 0          test          1102    security        1107     application_name
# 1          test          1102    security        1107     identity_pool_id
# 2          test          1102    security        1107               remote
# 3          test          1102    security        1107    remote_merge_path
# 4          test          1102    security        1107  user_pool_client_id
# 5          test          1102    security        1107         user_pool_id
#
#    config_oid  internal  temporary  \
# 0        1274     False      False
# 1        1280     False      False
# 2        1286     False      False
# 3        1292     False      False
# 4        1298     False      False
# 5        1304     False      False
#
#                                      config_value
# 0                                            test
# 1  us-east-1:3aa03da0-b11e-444d-ad5d-ec7e4844819f
# 2         s3://test-data-440955376164/merged_data
# 3           s3://test-public-storage-440955376164
# 4                      2ckshe5jnhi3cc2akodabuigct
# 5                             us-east-1_tKxja4leu

# %%
connection.execute("select * from duckdb_secrets();").fetch_df()
# Out:
#       name type provider  persistent storage                    scope  \
# 0  vaultdb   s3   config       False  memory  [s3://, s3n://, s3a://]
#
#                                        secret_string
# 0  name=vaultdb;type=s3;provider=config;serializa...

# %%
connection.execute("select * from information_schema.tables").fetchdf()
# Out:
#    table_catalog table_schema               table_name  table_type  \
# 0           test         main                  actions  BASE TABLE
# 1           test         main                another_T  BASE TABLE
# 2           test         main            balance_sheet  BASE TABLE
# 3           test         main                 cashflow  BASE TABLE
# 4           test         main                    demo2  BASE TABLE
# 5           test         main                dividends  BASE TABLE
# 6           test         main           earnings_dates  BASE TABLE
# 7           test         main              income_stmt  BASE TABLE
# 8           test         main        insider_purchases  BASE TABLE
# 9           test         main   insider_roster_holders  BASE TABLE
# 10          test         main     insider_transactions  BASE TABLE
# 11          test         main    institutional_holders  BASE TABLE
# 12          test         main            major_holders  BASE TABLE
# 13          test         main       mutualfund_holders  BASE TABLE
# 14          test         main               news_links  BASE TABLE
# 15          test         main             option_chain  BASE TABLE
# 16          test         main  quarterly_balance_sheet  BASE TABLE
# 17          test         main       quarterly_cashflow  BASE TABLE
# 18          test         main    quarterly_income_stmt  BASE TABLE
# 19          test         main                    quote  BASE TABLE
# 20          test         main          recommendations  BASE TABLE
# 21          test         main  recommendations_summary  BASE TABLE
# 22          test         main       shares_outstanding  BASE TABLE
# 23          test         main                   splits  BASE TABLE
# 24          test         main         tbl_ProductSales  BASE TABLE
# 25          test         main                  tickers  BASE TABLE
# 26          test         main      upgrades_downgrades  BASE TABLE
#
#    self_referencing_column_name reference_generation  \
# 0                          None                 None
# 1                          None                 None
# 2                          None                 None
# 3                          None                 None
# 4                          None                 None
# 5                          None                 None
# 6                          None                 None
# 7                          None                 None
# 8                          None                 None
# 9                          None                 None
# 10                         None                 None
# 11                         None                 None
# 12                         None                 None
# 13                         None                 None
# 14                         None                 None
# 15                         None                 None
# 16                         None                 None
# 17                         None                 None
# 18                         None                 None
# 19                         None                 None
# 20                         None                 None
# 21                         None                 None
# 22                         None                 None
# 23                         None                 None
# 24                         None                 None
# 25                         None                 None
# 26                         None                 None
#
#    user_defined_type_catalog user_defined_type_schema user_defined_type_name  \
# 0                       None                     None                   None
# 1                       None                     None                   None
# 2                       None                     None                   None
# 3                       None                     None                   None
# 4                       None                     None                   None
# 5                       None                     None                   None
# 6                       None                     None                   None
# 7                       None                     None                   None
# 8                       None                     None                   None
# 9                       None                     None                   None
# 10                      None                     None                   None
# 11                      None                     None                   None
# 12                      None                     None                   None
# 13                      None                     None                   None
# 14                      None                     None                   None
# 15                      None                     None                   None
# 16                      None                     None                   None
# 17                      None                     None                   None
# 18                      None                     None                   None
# 19                      None                     None                   None
# 20                      None                     None                   None
# 21                      None                     None                   None
# 22                      None                     None                   None
# 23                      None                     None                   None
# 24                      None                     None                   None
# 25                      None                     None                   None
# 26                      None                     None                   None
#
#    is_insertable_into is_typed commit_action TABLE_COMMENT
# 0                 YES       NO          None          None
# 1                 YES       NO          None          None
# 2                 YES       NO          None          None
# 3                 YES       NO          None          None
# 4                 YES       NO          None          None
# 5                 YES       NO          None          None
# 6                 YES       NO          None          None
# 7                 YES       NO          None          None
# 8                 YES       NO          None          None
# 9                 YES       NO          None          None
# 10                YES       NO          None          None
# 11                YES       NO          None          None
# 12                YES       NO          None          None
# 13                YES       NO          None          None
# 14                YES       NO          None          None
# 15                YES       NO          None          None
# 16                YES       NO          None          None
# 17                YES       NO          None          None
# 18                YES       NO          None          None
# 19                YES       NO          None          None
# 20                YES       NO          None          None
# 21                YES       NO          None          None
# 22                YES       NO          None          None
# 23                YES       NO          None          None
# 24                YES       NO          None          None
# 25                YES       NO          None          None
# 26                YES       NO          None          None

# %%
connection.execute("SET timezone='America/New_York';")
connection.execute("select * from quote where date='2024-06-24'").fetchdf()
# Out:
# ---------------------------------------------------------------------------
# UnknownTimeZoneError                      Traceback (most recent call last)
# Cell In[6], line 3
#       1 #import pytz
#       2 #connection.execute("SET timezone='America/New_York';")
# ----> 3 connection.execute("select * from quote where date='2024-06-24'").fetchdf()
#
# File /var/lang/lib/python3.12/site-packages/pandas/core/accessor.py:112, in PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f(self, *args, **kwargs)
#     111 def f(self, *args, **kwargs):
# --> 112     return self._delegate_method(name, *args, **kwargs)
#
# File /var/lang/lib/python3.12/site-packages/pandas/core/indexes/accessors.py:132, in Properties._delegate_method(self, name, *args, **kwargs)
#     129 values = self._get_values()
#     131 method = getattr(values, name)
# --> 132 result = method(*args, **kwargs)
#     134 if not is_list_like(result):
#     135     return result
#
# File /var/lang/lib/python3.12/site-packages/pandas/core/indexes/datetimes.py:283, in DatetimeIndex.tz_convert(self, tz)
#     281 @doc(DatetimeArray.tz_convert)
#     282 def tz_convert(self, tz) -> Self:
# --> 283     arr = self._data.tz_convert(tz)
#     284     return type(self)._simple_new(arr, name=self.name, refs=self._references)
#
# File /var/lang/lib/python3.12/site-packages/pandas/core/arrays/datetimes.py:911, in DatetimeArray.tz_convert(self, tz)
#     847 def tz_convert(self, tz) -> Self:
#     848     """
#     849     Convert tz-aware Datetime Array/Index from one time zone to another.
#     850
#    (...)
#     909                     dtype='datetime64[ns]', freq='h')
#     910     """
# --> 911     tz = timezones.maybe_get_tz(tz)
#     913     if self.tz is None:
#     914         # tz naive, use tz_localize
#     915         raise TypeError(
#     916             "Cannot convert tz-naive timestamps, use tz_localize to localize"
#     917         )
#
# File timezones.pyx:145, in pandas._libs.tslibs.timezones.maybe_get_tz()
#
# File timezones.pyx:170, in pandas._libs.tslibs.timezones.maybe_get_tz()
#
# File /var/lang/lib/python3.12/site-packages/pytz/__init__.py:188, in timezone(zone)
#     186             fp.close()
#     187     else:
# --> 188         raise UnknownTimeZoneError(zone)
#     190 return _tzinfo_cache[zone]
#
# UnknownTimeZoneError: '/etc/localtime'

# %% [markdown]
# Data Inheritance

# %%
connection.execute(f"PRAGMA enable_data_inheritance;")
connection.execute("SELECT * FROM quote").fetchdf()
# Out:
#                           date        open        high         low  \
# 0    1986-03-13 00:00:00-05:00    0.088542    0.101563    0.088542
# 1    1986-03-14 00:00:00-05:00    0.097222    0.102431    0.097222
# 2    1986-03-17 00:00:00-05:00    0.100694    0.103299    0.100694
# 3    1986-03-18 00:00:00-05:00    0.102431    0.103299    0.098958
# 4    1986-03-19 00:00:00-05:00    0.099826    0.100694    0.097222
# ...                        ...         ...         ...         ...
# 9642 2024-06-17 00:00:00-04:00  442.589996  450.940002  440.720001
# 9643 2024-06-18 00:00:00-04:00  449.709991  450.140015  444.890015
# 9644 2024-06-20 00:00:00-04:00  446.299988  446.529999  441.269989
# 9645 2024-06-21 00:00:00-04:00  447.380005  450.579987  446.510010
# 9646 2024-06-24 00:00:00-04:00  449.799988  452.750000  446.410004
#
#            close      volume  dividends  stock_splits symbol
# 0       0.097222  1031788800        0.0           0.0   MSFT
# 1       0.100694   308160000        0.0           0.0   MSFT
# 2       0.102431   133171200        0.0           0.0   MSFT
# 3       0.099826    67766400        0.0           0.0   MSFT
# 4       0.098090    47894400        0.0           0.0   MSFT
# ...          ...         ...        ...           ...    ...
# 9642  448.369995    20790000        0.0           0.0   MSFT
# 9643  446.339996    17112500        0.0           0.0   MSFT
# 9644  445.700012    19877400        0.0           0.0   MSFT
# 9645  449.779999    34187100        0.0           0.0   MSFT
# 9646  447.670013    15666601        0.0           0.0   MSFT
#
# [9647 rows x 9 columns]

# %% [markdown]
# Insert Data Locally

# %%
connection.execute("INSERT INTO another_T VALUES (81,92,93,94,95,96,97,98)")

# %% [markdown]
# View Local Data

# %%
connection.execute(f"PRAGMA disable_data_inheritance;")
connection.execute("SELECT * FROM quote").fetchdf()
# Out:
# Empty DataFrame
# Columns: [date, open, high, low, close, volume, dividends, stock_splits, symbol]
# Index: []

# %% [markdown]
# Enable Inheritance

# %%
connection.execute(f"PRAGMA enable_data_inheritance;")
connection.execute("SELECT * FROM another_T").fetchdf()
# Out:
#    col1  col2  col3  col4  col5  col6  col7  col8
# 0    81    92    93    94    95    96    97    98

# %% [markdown]
# Push local Data

# %%
connection.execute('PUSH DATABASE dev;').fetchdf()
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# Truncate Local data

# %%
connection.execute('TRUNCATE DATABASE test;').fetchdf()
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# View remote Data

# %%
connection.execute(f"PRAGMA enable_data_inheritance;")
connection.execute("SELECT * FROM another_T").fetchdf()
# Out:
#    col1  col2  col3  col4  col5  col6  col7  col8
# 0    81    92    93    94    95    96    97    98

# %% [markdown]
# Create Objects Locally

# %%
connection.execute('BEGIN TRANSACTION;')
connection.execute('CREATE TABLE demo2 (col1 INT, col2 INT, col3 INT, col4 INT, col5 INT, col6 INT, col7 INT, col8 INT)')
connection.execute("INSERT INTO demo2 VALUES (1,2,3,4,5,6,7,8), (11,22,33,44,55,66,77,88), (111,222,333,444,555,666,777,888), (1111,2222,3333,4444,5555,6666,7777,8888)")
connection.execute('COMMIT;')

# %% [markdown]
# Push Schema Changes on to server

# %%
connection.execute('PUSH DATABASE dev;').fetchdf()
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []
